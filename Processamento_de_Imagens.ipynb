# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermercarv/Ciencia-Analise-de-Dados-com-Python/blob/main/Processamento_de_Imagens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install image_processing

from image_processing.utils import io, plot
from image_processing.processing import combination, transformation

# %%
image1 = io.read_image("/content/drive/MyDrive/imagens/bitcoin-2007769_1920.jpg")
image2 = io.read_image("/content/drive/MyDrive/imagens/bitcoin-6304115_1920.jpg")
image3 =io.read_image("/content/drive/MyDrive/imagens/dollars-499481_1920.jpg")

# %%
plot.plot_image(image1)
plot.plot_image(image3)

# %%
result_image = combination.transfer_histogram(image1, image3)
plot.plot_result(image1, image3, result_image)
